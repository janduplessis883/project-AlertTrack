# %%
import requests
from bs4 import BeautifulSoup
from bs4.element import Tag
from urllib.parse import urljoin
import pandas as pd
from firecrawl import FirecrawlApp
import os

# It's recommended to set the API key as an environment variable
# For this example, we'll use the provided key directly, but this is not best practice
FIRECRAWL_API_KEY = os.getenv('FIRECRAWL_API_KEY')
# Initialize FirecrawlApp
# It will automatically use the FIRECRAWL_API_KEY environment variable if set,
# otherwise you can pass it as an argument: FirecrawlApp(api_key="YOUR_API_KEY")
app = FirecrawlApp(api_key=FIRECRAWL_API_KEY)

BASE_URL_DRUG_SAFETY = "https://www.gov.uk/drug-safety-update"

def scrape_drug_safety_updates():
    """
    Scrapes the list of drug safety updates, including dates, and then each linked page for detailed info using Firecrawl.
    Returns a pandas DataFrame.
    """
    listing_data = []

    print(f"Scraping listing page with requests: {BASE_URL_DRUG_SAFETY}")
    response = requests.get(BASE_URL_DRUG_SAFETY)
    response.raise_for_status()
    soup = BeautifulSoup(response.content, 'html.parser')

    alerts = []
    for li in soup.select('ul.gem-c-document-list li'):
        link = li.find('a')
        # Find the date text directly within the list item
        # Only proceed if a link is found
        if link and isinstance(link, Tag): # Ensure link is a Tag object
            date_text = li.get_text(strip=True).replace(link.get_text(strip=True), '').strip()

            if date_text:
                title = link.get_text(strip=True)
                href_attr = link.get('href') # Use .get() to safely retrieve attribute
                if href_attr and isinstance(href_attr, str): # Ensure href_attr is a string
                    full_url = urljoin(BASE_URL_DRUG_SAFETY, href_attr)

                    # Assuming the date format is consistent, you might need to adjust this
                    # if the format varies.
                    published_date = pd.to_datetime(date_text, errors='coerce')

                    alerts.append({'publish_date': published_date, 'title': title, 'url': full_url})
    listing_data = alerts

    print(listing_data)
    df = pd.DataFrame(listing_data)
    return df

# %%
df = scrape_drug_safety_updates()
# Out:
# Scraping listing page with requests: https://www.gov.uk/drug-safety-update
# [{'publish_date': NaT, 'title': 'Abrysvo▼ (Pfizer RSV vaccine) and Arexvy▼ (GSK RSV vaccine): be alert to a small risk of Guillain-Barré syndrome following vaccination in older adults', 'url': 'https://www.gov.uk/drug-safety-update/abrysvov-pfizer-rsv-vaccine-and-arexvyv-gsk-rsv-vaccine-be-alert-to-a-small-risk-of-guillain-barre-syndrome-following-vaccination-in-older-adults'}, {'publish_date': NaT, 'title': 'IXCHIQ Chikungunya vaccine: temporary suspension in people aged 65 years or older', 'url': 'https://www.gov.uk/drug-safety-update/ixchiq-chikungunya-vaccine-temporary-suspension-in-people-aged-65-years-or-older'}, {'publish_date': NaT, 'title': 'Valproate (Belvo, Convulex, Depakote, Dyzantil, Epilim, Epilim Chrono or Chronosphere, Episenta, Epival, and Syonell▼): updated safety and educational materials to support patient discussion on reproductive risks', 'url': 'https://www.gov.uk/drug-safety-update/valproate-belvo-convulex-depakote-dyzantil-epilim-epilim-chrono-or-chronosphere-episenta-epival-and-syonellv-updated-safety-and-educational-materials-to-support-patient-discussion-on-reproductive-risks'}, {'publish_date': NaT, 'title': 'Thiopurines and intrahepatic cholestasis of pregnancy', 'url': 'https://www.gov.uk/drug-safety-update/thiopurines-and-intrahepatic-cholestasis-of-pregnancy'}, {'publish_date': NaT, 'title': 'Kaftrio▼ (Ivacaftor, tezacaftor, elexacaftor): risk of psychological side effects', 'url': 'https://www.gov.uk/drug-safety-update/kaftriov-ivacaftor-tezacaftor-elexacaftor-risk-of-psychological-side-effects'}, {'publish_date': NaT, 'title': 'Short-acting beta 2 agonists (SABA) (salbutamol and terbutaline): reminder of the risks from overuse in asthma and to be aware of changes in the SABA prescribing guidelines', 'url': 'https://www.gov.uk/drug-safety-update/short-acting-beta-2-agonists-saba-salbutamol-and-terbutaline-reminder-of-the-risks-from-overuse-in-asthma-and-to-be-aware-of-changes-in-the-saba-prescribing-guidelines'}, {'publish_date': NaT, 'title': 'Fezolinetant▼(Veoza): risk of liver injury; new recommendations to minimise risk', 'url': 'https://www.gov.uk/drug-safety-update/fezolinetantv-veoza-risk-of-liver-injury-new-recommendations-to-minimise-risk'}, {'publish_date': NaT, 'title': 'Prolonged-release opioids: Removal of indication for relief of post-operative pain', 'url': 'https://www.gov.uk/drug-safety-update/prolonged-release-opioids-removal-of-indication-for-relief-of-post-operative-pain'}, {'publish_date': NaT, 'title': 'Letters and medicine recalls sent to healthcare professionals in January 2025', 'url': 'https://www.gov.uk/drug-safety-update/letters-and-medicine-recalls-sent-to-healthcare-professionals-in-january-2025'}, {'publish_date': NaT, 'title': 'Valproate (Belvo, Convulex, Depakote, Dyzantil, Epilim, Epilim Chrono or  Chronosphere, Episenta, Epival, and Syonell▼): review by  two specialists is required for initiating valproate but not for  male patients already taking valproate', 'url': 'https://www.gov.uk/drug-safety-update/valproate-belvo-convulex-depakote-dyzantil-epilim-epilim-chrono-or-chronosphere-episenta-epival-and-syonellv-review-by-two-specialists-is-required-for-initiating-valproate-but-not-for-male-patients-already-taking-valproate'}, {'publish_date': NaT, 'title': 'GLP-1 and dual GIP/GLP-1 receptor agonists:\u202fpotential risk of pulmonary aspiration during general anaesthesia or deep sedation', 'url': 'https://www.gov.uk/drug-safety-update/glp-1-and-dual-gip-slash-glp-1-receptor-agonists-potential-risk-of-pulmonary-aspiration-during-general-anaesthesia-or-deep-sedation'}, {'publish_date': NaT, 'title': 'Letters and medicine recalls sent to healthcare professionals in December 2024', 'url': 'https://www.gov.uk/drug-safety-update/letters-and-medicine-recalls-sent-to-healthcare-professionals-in-december-2024'}, {'publish_date': NaT, 'title': 'Letters and medicine recalls sent to healthcare professionals in November 2024', 'url': 'https://www.gov.uk/drug-safety-update ...

# %%
df
# Out:
#    publish_date                                              title  \
# 0           NaT  Abrysvo▼ (Pfizer RSV vaccine) and Arexvy▼ (GSK...
# 1           NaT  IXCHIQ Chikungunya vaccine: temporary suspensi...
# 2           NaT  Valproate (Belvo, Convulex, Depakote, Dyzantil...
# 3           NaT  Thiopurines and intrahepatic cholestasis of pr...
# 4           NaT  Kaftrio▼ (Ivacaftor, tezacaftor, elexacaftor):...
# 5           NaT  Short-acting beta 2 agonists (SABA) (salbutamo...
# 6           NaT  Fezolinetant▼(Veoza): risk of liver injury; ne...
# 7           NaT  Prolonged-release opioids: Removal of indicati...
# 8           NaT  Letters and medicine recalls sent to healthcar...
# 9           NaT  Valproate (Belvo, Convulex, Depakote, Dyzantil...
# 10          NaT  GLP-1 and dual GIP/GLP-1 receptor agonists: po...
# 11          NaT  Letters and medicine recalls sent to healthcar...
# 12          NaT  Letters and medicine recalls sent to healthcar...
# 13          NaT  MedSafetyWeek November 2024: your Yellow Card ...
# 14          NaT  Letters and medicine recalls sent to healthcar...
# 15          NaT  GLP-1 receptor agonists: reminder of the poten...
# 16          NaT  Insulin pumps and continuous glucose monitorin...
# 17          NaT  Bromocriptine: monitor blood pressure when pre...
# 18          NaT  Letters and medicine recalls sent to healthcar...
# 19          NaT  Letters and medicine recalls sent to healthcar...
# 20          NaT  Valproate use in men: as a precaution, men and...
# 21          NaT  Yellow Card Biobank: call to contribute to stu...
# 22          NaT  Letters and medicine recalls sent to healthcar...
# 23          NaT  Epimax Ointment and Epimax Paraffin-Free Ointm...
# 24          NaT  Letters and medicine recalls sent to healthcar...
# 25          NaT  Topiramate (Topamax): introduction of new safe...
# 26          NaT  Warfarin: be alert to the risk of drug interac...
# 27          NaT  Letters and medicine recalls sent to healthcar...
# 28          NaT  Topical steroids: introduction of new labellin...
# 29          NaT  Letters and medicine recalls sent to healthcar...
# 30          NaT  Finasteride: reminder of the risk psychiatric ...
# 31          NaT  Montelukast: reminder of the risk of neuropsyc...
# 32          NaT  Letters and medicine recalls sent to healthcar...
# 33          NaT  Letters and medicine recalls sent to healthcar...
# 34          NaT  Codeine linctus (codeine oral solutions): recl...
# 35          NaT  Pseudoephedrine: very rare risk of posterior r...
# 36          NaT  Letters and medicine recalls sent to healthcar...
# 37          NaT  Valproate (Belvo, Convulex, Depakote, Dyzantil...
# 38          NaT  Fluoroquinolone antibiotics: must now only be ...
# 39          NaT  Omega-3-acid ethyl ester medicines (Omacor/Ter...
# 40          NaT  Letters and medicine recalls sent to healthcar...
# 41          NaT  Aripiprazole (Abilify and generic brands): ris...
# 42          NaT  Vitamin B12 (hydroxocobalamin, cyanocobalamin)...
# 43          NaT  Letters and medicine recalls sent to healthcar...
# 44          NaT  Ozempic▼(semaglutide) and Saxenda (liraglutide...
# 45          NaT  Nirmatrelvir, ritonavir (Paxlovid▼): be alert ...
# 46          NaT  E-cigarette use or vaping: reminder to remain ...
# 47          NaT  Letters and medicine recalls sent to healthcar...
# 48          NaT  Isotretinoin (Roaccutane▼): introduction of ne...
# 49          NaT  MedSafetyWeek November 2023: your Yellow Card ...
#
#                                                   url
# 0   https://www.gov.uk/drug-safety-update/abrysvov...
# 1   https://www.gov.uk/drug-safety-update/ixchiq-c...
# 2   https://www.gov.uk/drug-safety-update/valproat...
# 3   https://www.gov.uk/drug-safety-update/thiopuri...
# 4   https://www.gov.uk/drug-safety-update/kaftriov...
# 5   https://www.gov.uk/drug-safety-update/short-ac...
# 6   https://www.gov.uk/drug-safety-update/fezoline...
# 7   https://www.gov.uk/drug-safety-update/prolonge...
# 8   https://www.gov.uk/drug-safety-update/letters-...
# 9   https://www.gov.uk/drug-safety-update/valproat...
# 10  https://www.gov.uk/drug-safety-update/glp-1-an...
# 11  https://www.gov.uk/drug-safety-update/letters-...
# 12  https://www.gov.uk/drug-safety-update/letters-...
# 13  https://www.gov.uk/drug-safety-update/medsafet...
# 14  https://www.gov.uk/drug-safety-update/letters-...
# 15  https://www.gov.uk/drug-safety-update/glp-1-re...
# 16  https://www.gov.uk/drug-safety-update/insulin-...
# 17  https://www.gov.uk/drug-safety-update/bromocri...
# 18  https://www.gov.uk/drug-safety-update/letters-...
# 19  https://www.gov.uk/drug-safety-update/letters-...
# 20  https://www.gov.uk/drug-safety-update/valproat...
# 21  https://www.gov.uk/drug-safety-update/yellow-c...
# 22  https://www.gov.uk/drug-safety-update/letters-...
# 23  https://www.gov.uk/drug-safety-update/epimax-o...
# 24  https://www.gov.uk/drug-safety-update/letters-...
# 25  https://www.gov.uk/drug-safety-update/topirama...
# 26  https://www.gov.uk/drug-safety-update/warfarin...
# 27  https://www.gov.uk/drug-safety-update/letters-...
# 28  https://www.gov.uk/drug-safety-update/topical-...
# 29  https://www.gov.uk/drug-safety-update/letters-...
# 30  https://www.gov.uk/drug-safety-update/finaster...
# 31  https://www.gov.uk/drug-safety-update/monteluk...
# 32  https://www.gov.uk/drug-safety-update/letters-...
# 33  https://www.gov.uk/drug-safety-update/letters-...
# 34  https://www.gov.uk/drug-safety-update/codeine-...
# 35  https://www.gov.uk/drug-safety-update/pseudoep...
# 36  https://www.gov.uk/drug-safety-update/letters-...
# 37  https://www.gov.uk/drug-safety-update/valproat...
# 38  https://www.gov.uk/drug-safety-update/fluoroqu...
# 39  https://www.gov.uk/drug-safety-update/omega-3-...
# 40  https://www.gov.uk/drug-safety-update/letters-...
# 41  https://www.gov.uk/drug-safety-update/aripipra...
# 42  https://www.gov.uk/drug-safety-update/vitamin-...
# 43  https://www.gov.uk/drug-safety-update/letters-...
# 44  https://www.gov.uk/drug-safety-update/ozempicv...
# 45  https://www.gov.uk/drug-safety-update/nirmatre...
# 46  https://www.gov.uk/drug-safety-update/e-cigare...
# 47  https://www.gov.uk/drug-safety-update/letters-...
# 48  https://www.gov.uk/drug-safety-update/isotreti...
# 49  https://www.gov.uk/drug-safety-update/medsafet...

# %%
from firecrawl import FirecrawlApp, ScrapeOptions
from tqdm import tqdm
import time

app = FirecrawlApp(api_key=os.getenv('FIRECRAWL_API_KEY'))

detail = []
for index, row in tqdm(df.iterrows(),total=49):
    url = row['url']
    scrape_status = app.scrape_url(url, formats=['markdown'])
    markdown_text = scrape_status.markdown
    detail.append(markdown_text)
    time.sleep(10)
df['detail'] = detail
# Out:
#   2%|██▋                                                                                                                              | 1/49 [00:23<18:26, 23.05s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 12
#      10     markdown_text = scrape_status.markdown
#      11     detail.append(markdown_text)
# ---> 12     time.sleep(10)
#      13 df['detail'] = detail
#
# KeyboardInterrupt:

# %%
df
# Out:
#    publish_date                                              title  \
# 0           NaT  Abrysvo▼ (Pfizer RSV vaccine) and Arexvy▼ (GSK...
# 1           NaT  IXCHIQ Chikungunya vaccine: temporary suspensi...
# 2           NaT  Valproate (Belvo, Convulex, Depakote, Dyzantil...
# 3           NaT  Thiopurines and intrahepatic cholestasis of pr...
# 4           NaT  Kaftrio▼ (Ivacaftor, tezacaftor, elexacaftor):...
# 5           NaT  Short-acting beta 2 agonists (SABA) (salbutamo...
# 6           NaT  Fezolinetant▼(Veoza): risk of liver injury; ne...
# 7           NaT  Prolonged-release opioids: Removal of indicati...
# 8           NaT  Letters and medicine recalls sent to healthcar...
# 9           NaT  Valproate (Belvo, Convulex, Depakote, Dyzantil...
# 10          NaT  GLP-1 and dual GIP/GLP-1 receptor agonists: po...
# 11          NaT  Letters and medicine recalls sent to healthcar...
# 12          NaT  Letters and medicine recalls sent to healthcar...
# 13          NaT  MedSafetyWeek November 2024: your Yellow Card ...
# 14          NaT  Letters and medicine recalls sent to healthcar...
# 15          NaT  GLP-1 receptor agonists: reminder of the poten...
# 16          NaT  Insulin pumps and continuous glucose monitorin...
# 17          NaT  Bromocriptine: monitor blood pressure when pre...
# 18          NaT  Letters and medicine recalls sent to healthcar...
# 19          NaT  Letters and medicine recalls sent to healthcar...
# 20          NaT  Valproate use in men: as a precaution, men and...
# 21          NaT  Yellow Card Biobank: call to contribute to stu...
# 22          NaT  Letters and medicine recalls sent to healthcar...
# 23          NaT  Epimax Ointment and Epimax Paraffin-Free Ointm...
# 24          NaT  Letters and medicine recalls sent to healthcar...
# 25          NaT  Topiramate (Topamax): introduction of new safe...
# 26          NaT  Warfarin: be alert to the risk of drug interac...
# 27          NaT  Letters and medicine recalls sent to healthcar...
# 28          NaT  Topical steroids: introduction of new labellin...
# 29          NaT  Letters and medicine recalls sent to healthcar...
# 30          NaT  Finasteride: reminder of the risk psychiatric ...
# 31          NaT  Montelukast: reminder of the risk of neuropsyc...
# 32          NaT  Letters and medicine recalls sent to healthcar...
# 33          NaT  Letters and medicine recalls sent to healthcar...
# 34          NaT  Codeine linctus (codeine oral solutions): recl...
# 35          NaT  Pseudoephedrine: very rare risk of posterior r...
# 36          NaT  Letters and medicine recalls sent to healthcar...
# 37          NaT  Valproate (Belvo, Convulex, Depakote, Dyzantil...
# 38          NaT  Fluoroquinolone antibiotics: must now only be ...
# 39          NaT  Omega-3-acid ethyl ester medicines (Omacor/Ter...
# 40          NaT  Letters and medicine recalls sent to healthcar...
# 41          NaT  Aripiprazole (Abilify and generic brands): ris...
# 42          NaT  Vitamin B12 (hydroxocobalamin, cyanocobalamin)...
# 43          NaT  Letters and medicine recalls sent to healthcar...
# 44          NaT  Ozempic▼(semaglutide) and Saxenda (liraglutide...
# 45          NaT  Nirmatrelvir, ritonavir (Paxlovid▼): be alert ...
# 46          NaT  E-cigarette use or vaping: reminder to remain ...
# 47          NaT  Letters and medicine recalls sent to healthcar...
# 48          NaT  Isotretinoin (Roaccutane▼): introduction of ne...
# 49          NaT  MedSafetyWeek November 2023: your Yellow Card ...
#
#                                                   url  \
# 0   https://www.gov.uk/drug-safety-update/abrysvov...
# 1   https://www.gov.uk/drug-safety-update/ixchiq-c...
# 2   https://www.gov.uk/drug-safety-update/valproat...
# 3   https://www.gov.uk/drug-safety-update/thiopuri...
# 4   https://www.gov.uk/drug-safety-update/kaftriov...
# 5   https://www.gov.uk/drug-safety-update/short-ac...
# 6   https://www.gov.uk/drug-safety-update/fezoline...
# 7   https://www.gov.uk/drug-safety-update/prolonge...
# 8   https://www.gov.uk/drug-safety-update/letters-...
# 9   https://www.gov.uk/drug-safety-update/valproat...
# 10  https://www.gov.uk/drug-safety-update/glp-1-an...
# 11  https://www.gov.uk/drug-safety-update/letters-...
# 12  https://www.gov.uk/drug-safety-update/letters-...
# 13  https://www.gov.uk/drug-safety-update/medsafet...
# 14  https://www.gov.uk/drug-safety-update/letters-...
# 15  https://www.gov.uk/drug-safety-update/glp-1-re...
# 16  https://www.gov.uk/drug-safety-update/insulin-...
# 17  https://www.gov.uk/drug-safety-update/bromocri...
# 18  https://www.gov.uk/drug-safety-update/letters-...
# 19  https://www.gov.uk/drug-safety-update/letters-...
# 20  https://www.gov.uk/drug-safety-update/valproat...
# 21  https://www.gov.uk/drug-safety-update/yellow-c...
# 22  https://www.gov.uk/drug-safety-update/letters-...
# 23  https://www.gov.uk/drug-safety-update/epimax-o...
# 24  https://www.gov.uk/drug-safety-update/letters-...
# 25  https://www.gov.uk/drug-safety-update/topirama...
# 26  https://www.gov.uk/drug-safety-update/warfarin...
# 27  https://www.gov.uk/drug-safety-update/letters-...
# 28  https://www.gov.uk/drug-safety-update/topical-...
# 29  https://www.gov.uk/drug-safety-update/letters-...
# 30  https://www.gov.uk/drug-safety-update/finaster...
# 31  https://www.gov.uk/drug-safety-update/monteluk...
# 32  https://www.gov.uk/drug-safety-update/letters-...
# 33  https://www.gov.uk/drug-safety-update/letters-...
# 34  https://www.gov.uk/drug-safety-update/codeine-...
# 35  https://www.gov.uk/drug-safety-update/pseudoep...
# 36  https://www.gov.uk/drug-safety-update/letters-...
# 37  https://www.gov.uk/drug-safety-update/valproat...
# 38  https://www.gov.uk/drug-safety-update/fluoroqu...
# 39  https://www.gov.uk/drug-safety-update/omega-3-...
# 40  https://www.gov.uk/drug-safety-update/letters-...
# 41  https://www.gov.uk/drug-safety-update/aripipra...
# 42  https://www.gov.uk/drug-safety-update/vitamin-...
# 43  https://www.gov.uk/drug-safety-update/letters-...
# 44  https://www.gov.uk/drug-safety-update/ozempicv...
# 45  https://www.gov.uk/drug-safety-update/nirmatre...
# 46  https://www.gov.uk/drug-safety-update/e-cigare...
# 47  https://www.gov.uk/drug-safety-update/letters-...
# 48  https://www.gov.uk/drug-safety-update/isotreti...
# 49  https://www.gov.uk/drug-safety-update/medsafet...
#
#                                                detail
# 0   ## Cookies on GOV.UK\n\nWe use some essential ...
# 1   ## Cookies on GOV.UK\n\nWe use some essential ...
# 2   ## Cookies on GOV.UK\n\nWe use some essential ...
# 3   ## Cookies on GOV.UK\n\nWe use some essential ...
# 4   ## Cookies on GOV.UK\n\nWe use some essential ...
# 5   ## Cookies on GOV.UK\n\nWe use some essential ...
# 6   ## Cookies on GOV.UK\n\nWe use some essential ...
# 7   ## Cookies on GOV.UK\n\nWe use some essential ...
# 8   ## Cookies on GOV.UK\n\nWe use some essential ...
# 9   ## Cookies on GOV.UK\n\nWe use some essential ...
# 10  ## Cookies on GOV.UK\n\nWe use some essential ...
# 11  ## Cookies on GOV.UK\n\nWe use some essential ...
# 12  ## Cookies on GOV.UK\n\nWe use some essential ...
# 13  ## Cookies on GOV.UK\n\nWe use some essential ...
# 14  ## Cookies on GOV.UK\n\nWe use some essential ...
# 15  ## Cookies on GOV.UK\n\nWe use some essential ...
# 16  ## Cookies on GOV.UK\n\nWe use some essential ...
# 17  ## Cookies on GOV.UK\n\nWe use some essential ...
# 18  ## Cookies on GOV.UK\n\nWe use some essential ...
# 19  ## Cookies on GOV.UK\n\nWe use some essential ...
# 20  ## Cookies on GOV.UK\n\nWe use some essential ...
# 21  ## Cookies on GOV.UK\n\nWe use some essential ...
# 22  ## Cookies on GOV.UK\n\nWe use some essential ...
# 23  ## Cookies on GOV.UK\n\nWe use some essential ...
# 24  ## Cookies on GOV.UK\n\nWe use some essential ...
# 25  ## Cookies on GOV.UK\n\nWe use some essential ...
# 26  ## Cookies on GOV.UK\n\nWe use some essential ...
# 27  ## Cookies on GOV.UK\n\nWe use some essential ...
# 28  ## Cookies on GOV.UK\n\nWe use some essential ...
# 29  ## Cookies on GOV.UK\n\nWe use some essential ...
# 30  ## Cookies on GOV.UK\n\nWe use some essential ...
# 31  ## Cookies on GOV.UK\n\nWe use some essential ...
# 32  ## Cookies on GOV.UK\n\nWe use some essential ...
# 33  ## Cookies on GOV.UK\n\nWe use some essential ...
# 34  ## Cookies on GOV.UK\n\nWe use some essential ...
# 35  ## Cookies on GOV.UK\n\nWe use some essential ...
# 36  ## Cookies on GOV.UK\n\nWe use some essential ...
# 37  ## Cookies on GOV.UK\n\nWe use some essential ...
# 38  ## Cookies on GOV.UK\n\nWe use some essential ...
# 39  ## Cookies on GOV.UK\n\nWe use some essential ...
# 40  ## Cookies on GOV.UK\n\nWe use some essential ...
# 41  ## Cookies on GOV.UK\n\nWe use some essential ...
# 42  ## Cookies on GOV.UK\n\nWe use some essential ...
# 43  ## Cookies on GOV.UK\n\nWe use some essential ...
# 44  ## Cookies on GOV.UK\n\nWe use some essential ...
# 45  ## Cookies on GOV.UK\n\nWe use some essential ...
# 46  ## Cookies on GOV.UK\n\nWe use some essential ...
# 47  ## Cookies on GOV.UK\n\nWe use some essential ...
# 48  ## Cookies on GOV.UK\n\nWe use some essential ...
# 49  ## Cookies on GOV.UK\n\nWe use some essential ...

# %%
df.to_csv('data.csv', index=False)

# %%
# !pip install firecrawl
# Out:
# Collecting firecrawl
#   Downloading firecrawl-2.15.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: requests in /Users/jpltuk/.pyenv/versions/alerttrack/lib/python3.12/site-packages (from firecrawl) (2.32.4)
# Collecting python-dotenv (from firecrawl)
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Collecting websockets (from firecrawl)
#   Using cached websockets-15.0.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: nest-asyncio in /Users/jpltuk/.pyenv/versions/alerttrack/lib/python3.12/site-packages (from firecrawl) (1.6.0)
# Collecting pydantic (from firecrawl)
#   Using cached pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Collecting aiohttp (from firecrawl)
#   Downloading aiohttp-3.12.14-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.6 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp->firecrawl)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp->firecrawl)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in /Users/jpltuk/.pyenv/versions/alerttrack/lib/python3.12/site-packages (from aiohttp->firecrawl) (25.3.0)
# Collecting frozenlist>=1.1.1 (from aiohttp->firecrawl)
#   Using cached frozenlist-1.7.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (18 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->firecrawl)
#   Downloading multidict-6.6.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp->firecrawl)
#   Using cached propcache-0.3.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp->firecrawl)
#   Using cached yarl-1.20.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (73 kB)
# Requirement already satisfied: idna>=2.0 in /Users/jpltuk/.pyenv/versions/alerttrack/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp->firecrawl) (3.10)
# Requirement already satisfied: typing-extensions>=4.2 in /Users/jpltuk/.pyenv/versions/alerttrack/lib/python3.12/site-packages (from aiosignal>=1.4.0->aiohttp->firecrawl) (4.14.1)
# Collecting annotated-types>=0.6.0 (from pydantic->firecrawl)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic->firecrawl)
#   Using cached pydantic_core-2.33.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic->firecrawl)
#   Using cached typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/jpltuk/.pyenv/versions/alerttrack/lib/python3.12/site-packages (from requests->firecrawl) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jpltuk/.pyenv/versions/alerttrack/lib/python3.12/site-packages (from requests->firecrawl) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jpltuk/.pyenv/versions/alerttrack/lib/python3.12/site-packages (from requests->firecrawl) (2025.7.9)
# Downloading firecrawl-2.15.0-py3-none-any.whl (39 kB)
# Downloading aiohttp-3.12.14-cp312-cp312-macosx_11_0_arm64.whl (468 kB)
# Downloading multidict-6.6.3-cp312-cp312-macosx_11_0_arm64.whl (43 kB)
# Using cached yarl-1.20.1-cp312-cp312-macosx_11_0_arm64.whl (89 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached frozenlist-1.7.0-cp312-cp312-macosx_11_0_arm64.whl (46 kB)
# Using cached propcache-0.3.2-cp312-cp312-macosx_11_0_arm64.whl (43 kB)
# Using cached pydantic-2.11.7-py3-none-any.whl (444 kB)
# Using cached pydantic_core-2.33.2-cp312-cp312-macosx_11_0_arm64.whl (1.8 MB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Using cached websockets-15.0.1-cp312-cp312-macosx_11_0_arm64.whl (173 kB)
# Installing collected packages: websockets, typing-inspection, python-dotenv, pydantic-core, propcache, multidict, frozenlist, annotated-types, aiohappyeyeballs, yarl, pydantic, aiosignal, aiohttp, firecrawl
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14/14 [firecrawl] 12/14 [aiohttp]ydantic]
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.12.14 aiosignal-1.4.0 annotated-types-0.7.0 firecrawl-2.15.0 frozenlist-1.7.0 multidict-6.6.3 propcache-0.3.2 pydantic-2.11.7 pydantic-core-2.33.2 python-dotenv-1.1.1 typing-inspection-0.4.1 websockets-15.0.1 yarl-1.20.1

# %%
from firecrawl import FirecrawlApp, JsonConfig
from pydantic import BaseModel, Field
from typing import Optional
import time

# %%
class ExtractSchema(BaseModel):
    document_download_url: Optional[str] = Field(
        None,
        description="The full URL for the 'Download Document' link on the page. It should end with .pdf"
    )
    therapeutic_area: Optional[str] = Field(
        None,
        description="List of therapeutic areas that the alert applies to for example: General Practice, Pharmacy, Surgery etc"
    )

def extract_url(url: str, api_key: str) -> dict:
    app = FirecrawlApp(api_key=api_key)
    
    json_config = JsonConfig(schema=ExtractSchema)
    
    result = app.scrape_url(
        url,
        formats=["json"],
        json_options=json_config,
        only_main_content=True,
        timeout=120000
    )
    
    return result.json

# %%
df = pd.read_csv('../data/data.csv')
df.head()
# Out:
#   publish_date                                              title  \
# 0   2025-07-07  Abrysvo▼ (Pfizer RSV vaccine) and Arexvy▼ (GSK...
# 1   2025-06-18  IXCHIQ Chikungunya vaccine: temporary suspensi...
# 2   2025-06-10  Valproate (Belvo, Convulex, Depakote, Dyzantil...
# 3   2025-05-15  Thiopurines and intrahepatic cholestasis of pr...
# 4   2025-05-07  Kaftrio▼ (Ivacaftor, tezacaftor, elexacaftor):...
#
#                                                  url  \
# 0  https://www.gov.uk/drug-safety-update/abrysvov...
# 1  https://www.gov.uk/drug-safety-update/ixchiq-c...
# 2  https://www.gov.uk/drug-safety-update/valproat...
# 3  https://www.gov.uk/drug-safety-update/thiopuri...
# 4  https://www.gov.uk/drug-safety-update/kaftriov...
#
#                                               detail  alert_pdf  \
# 0  ## Cookies on GOV.UK\n\nWe use some essential ...        NaN
# 1  ## Cookies on GOV.UK\n\nWe use some essential ...        NaN
# 2  ## Cookies on GOV.UK\n\nWe use some essential ...        NaN
# 3  ## Cookies on GOV.UK\n\nWe use some essential ...        NaN
# 4  ## Cookies on GOV.UK\n\nWe use some essential ...        NaN
#
#                                                  pdf  \
# 0  https://assets.publishing.service.gov.uk/media...
# 1  https://assets.publishing.service.gov.uk/media...
# 2  https://assets.publishing.service.gov.uk/media...
# 3  https://assets.publishing.service.gov.uk/media...
# 4  https://assets.publishing.service.gov.uk/media...
#
#                                          therapeutic
# 0  Anaesthesia and intensive care, General practi...
# 1  Immunology and vaccination, Infection preventi...
# 2  General practice, Neurology, Obstetrics, gynae...
# 3  Cancer, Dermatology, GI, hepatology and pancre...
# 4  General practice, Pharmacy, Respiratory diseas...

# %%
pdf = []
therapeutic = []
from tqdm import tqdm

for index, row in tqdm(df.iterrows(), total=df.shape[0]):
    url = row['url']
    output = extract_url(url, os.getenv('FIRECRAWL_API_KEY'))

    time.sleep(8)
    pdf.append(output['document_download_url'])
    therapeutic.append(output['therapeutic_area'])

df['pdf'] = pdf
df['therapeutic'] = therapeutic
# Out:
#  84%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                     | 42/50 [08:49<01:40, 12.62s/it]
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/.pyenv/versions/alerttrack/lib/python3.12/site-packages/requests/models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/.pyenv/versions/3.12.9/lib/python3.12/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~/.pyenv/versions/3.12.9/lib/python3.12/json/decoder.py:338, in JSONDecoder.decode(self, s, _w)
#     334 """Return the Python representation of ``s`` (a ``str`` instance
#     335 containing a JSON document).
#     336
#     337 """
# --> 338 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     339 end = _w(s, end).end()
#
# File ~/.pyenv/versions/3.12.9/lib/python3.12/json/decoder.py:356, in JSONDecoder.raw_decode(self, s, idx)
#     355 except StopIteration as err:
# --> 356     raise JSONDecodeError("Expecting value", s, err.value) from None
#     357 return obj, end
#
# JSONDecodeError: Expecting value: line 2 column 1 (char 1)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# File ~/.pyenv/versions/alerttrack/lib/python3.12/site-packages/firecrawl/firecrawl.py:2332, in FirecrawlApp._handle_error(self, response, action)
#    2331 try:
# -> 2332     error_message = response.json().get('error', 'No error message provided.')
#    2333     error_details = response.json().get('details', 'No additional error details provided.')
#
# File ~/.pyenv/versions/alerttrack/lib/python3.12/site-packages/requests/models.py:980, in Response.json(self, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 980     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 2 column 1 (char 1)
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# Cell In[24], line 7
#       5 for index, row in tqdm(df.iterrows(), total=df.shape[0]):
#       6     url = row['url']
# ----> 7     output = extract_url(url, os.getenv('FIRECRAWL_API_KEY'))
#       9     time.sleep(8)
#      10     pdf.append(output['document_download_url'])
#
# Cell In[19], line 16, in extract_url(url, api_key)
#      12 app = FirecrawlApp(api_key=api_key)
#      14 json_config = JsonConfig(schema=ExtractSchema)
# ---> 16 result = app.scrape_url(
#      17     url,
#      18     formats=["json"],
#      19     json_options=json_config,
#      20     only_main_content=True,
#      21     timeout=120000
#      22 )
#      24 return result.json
#
# File ~/.pyenv/versions/alerttrack/lib/python3.12/site-packages/firecrawl/firecrawl.py:604, in FirecrawlApp.scrape_url(self, url, formats, include_tags, exclude_tags, only_main_content, wait_for, timeout, location, mobile, skip_tls_verification, remove_base64_images, block_ads, proxy, parse_pdf, extract, json_options, actions, change_tracking_options, max_age, store_in_cache, zero_data_retention, **kwargs)
#     602         raise Exception('Failed to parse Firecrawl response as JSON.')
#     603 else:
# --> 604     self._handle_error(response, 'scrape URL')
#
# File ~/.pyenv/versions/alerttrack/lib/python3.12/site-packages/firecrawl/firecrawl.py:2335, in FirecrawlApp._handle_error(self, response, action)
#    2333     error_details = response.json().get('details', 'No additional error details provided.')
#    2334 except:
# -> 2335     raise requests.exceptions.HTTPError(f'Failed to parse Firecrawl error response as JSON. Status code: {response.status_code}', response=response)
#    2337 message = self._get_error_message(response.status_code, action, error_message, error_details)
#    2339 # Raise an HTTPError with the custom message and attach the response
#
# HTTPError: Failed to parse Firecrawl error response as JSON. Status code: 502

# %%
pdf
# Out:
# ['https://assets.publishing.service.gov.uk/media/686bb9d3fe1a249e937cbd64/DSU_RSV_vaccine_-_final.pdf',
#  'https://assets.publishing.service.gov.uk/media/6852c872ff16d05c5e6aa6bb/IXCHIQ_-_DRUG_SAFETY_UPDATE_-_FINAL.pdf',
#  'https://assets.publishing.service.gov.uk/media/6846e91f4d039a010411f102/Valproate_RMM_DSU_-_Final.pdf',
#  'https://assets.publishing.service.gov.uk/media/6825b71d85c0250741b014a1/DSU_Thiopurines_and_intrahepatic_cholestasis_of_pregnancy_-_FINAL.pdf',
#  'https://assets.publishing.service.gov.uk/media/681a1db1fb59a222d4f17334/Kaftrio_DSU_FINAL_v2.pdf',
#  'https://assets.publishing.service.gov.uk/media/680a0f63382965132de1aa69/SABA_DSU_FINAL_PDF.pdf',
#  'https://assets.publishing.service.gov.uk/media/67f79c8049d2ffceecef2fee/Veoza_DSU_PDF_Final.pdf',
#  'https://assets.publishing.service.gov.uk/media/67d164ca0c569e0d48fb0a0a/Final_Prolonged-release_opioids_DSU.pdf',
#  'https://assets.publishing.service.gov.uk/media/67bde2e65d6b30e896ac6d35/Veoza_DHPC.pdf',
#  'https://assets.publishing.service.gov.uk/media/67ae07036e6c8d18118acd83/Valproate_DSU_February_2025_-_FINAL_PDF.pdf',
#  None,
#  'https://assets.publishing.service.gov.uk/media/6793b4e07b75412c254f4b2b/Dear_HCP_Medikinet_XL_caps_-_v1.1_Headed_Paper.pdf',
#  'https://assets.publishing.service.gov.uk/media/6759c3a64cbda57cacd34717/1_Welireg_Final.pdf',
#  None,
#  'https://assets.publishing.service.gov.uk/media/672a36c1fbd69e1861921b9c/Medroxyprogesterone_acetate_-_Risk_of_meningioma_and_measures_to_minimise_this_risk_-_to_publish.pdf',
#  'https://assets.publishing.service.gov.uk/media/671912baa36621334536b39d/Annex_1_GLP-1RA-containing_medicines.pdf',
#  None,
#  None,
#  'https://assets.publishing.service.gov.uk/media/67165caa4a6b12291ed99819/oxbryta.pdf',
#  'https://assets.publishing.service.gov.uk/media/66f3e39030536cb927482695/Dexdor_-_to_publish.pdf',
#  None,
#  None,
#  'https://assets.publishing.service.gov.uk/media/66c3596f2e8f04b086cdf3db/UK_DHPC-Final_CAR-T_cell.pdf',
#  None,
#  'https://assets.publishing.service.gov.uk/media/669a827f49b9c0597fdb00cd/Final_Vabysmo.pdf',
#  None,
#  None,
#  'https://assets.publishing.service.gov.uk/media/66716bd9a414415642692caf/Sodiofolin_-_to_publish_-_June_DSU.pdf',
#  None,
#  None,
#  None,
#  None,
#  'https://assets.publishing.service.gov.uk/media/66292d89b0ace32985a7e7d5/fiasp_to_publish.pdf',
#  'https://assets.publishing.service.gov.uk/media/66019cde65ca2fc1fa7da868/refixia-to_publish.pdf',
#  None,
#  None,
#  'https://assets.publishing.service.gov.uk/media/65ce2317c96cf3000c6a3840/Valproate_-_TO_PUBLISH.pdf',
#  'https://www.gov.uk/drug-safety-update/valproate-belvo-convulex-depakote-dyzantil-epilim-epilim-chrono-or-chronosphere-episenta-epival-and-syonellv-new-safety-and-educational-materials-to-support-regulatory-measures-in-men-and-women-under-55-years-of-age',
#  None,
#  None,
#  'https://assets.publishing.service.gov.uk/media/65aa76310ce931000ff731e9/DHPC_Oncaspar_-_TO_PUBLISH.pdf',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
pdf.append(None)

# %%
df['pdf'] = pdf

# %%
df.head()
# Out:
#   publish_date                                              title  \
# 0   2025-07-07  Abrysvo▼ (Pfizer RSV vaccine) and Arexvy▼ (GSK...
# 1   2025-06-18  IXCHIQ Chikungunya vaccine: temporary suspensi...
# 2   2025-06-10  Valproate (Belvo, Convulex, Depakote, Dyzantil...
# 3   2025-05-15  Thiopurines and intrahepatic cholestasis of pr...
# 4   2025-05-07  Kaftrio▼ (Ivacaftor, tezacaftor, elexacaftor):...
#
#                                                  url  \
# 0  https://www.gov.uk/drug-safety-update/abrysvov...
# 1  https://www.gov.uk/drug-safety-update/ixchiq-c...
# 2  https://www.gov.uk/drug-safety-update/valproat...
# 3  https://www.gov.uk/drug-safety-update/thiopuri...
# 4  https://www.gov.uk/drug-safety-update/kaftriov...
#
#                                               detail  alert_pdf  \
# 0  ## Cookies on GOV.UK\n\nWe use some essential ...        NaN
# 1  ## Cookies on GOV.UK\n\nWe use some essential ...        NaN
# 2  ## Cookies on GOV.UK\n\nWe use some essential ...        NaN
# 3  ## Cookies on GOV.UK\n\nWe use some essential ...        NaN
# 4  ## Cookies on GOV.UK\n\nWe use some essential ...        NaN
#
#                                                  pdf
# 0  https://assets.publishing.service.gov.uk/media...
# 1  https://assets.publishing.service.gov.uk/media...
# 2  https://assets.publishing.service.gov.uk/media...
# 3  https://assets.publishing.service.gov.uk/media...
# 4  https://assets.publishing.service.gov.uk/media...

# %%
therapeutic.append(None)

# %%
df['therapeutic'] = therapeutic

# %%
df.head()
# Out:
#   publish_date                                              title  \
# 0   2025-07-07  Abrysvo▼ (Pfizer RSV vaccine) and Arexvy▼ (GSK...
# 1   2025-06-18  IXCHIQ Chikungunya vaccine: temporary suspensi...
# 2   2025-06-10  Valproate (Belvo, Convulex, Depakote, Dyzantil...
# 3   2025-05-15  Thiopurines and intrahepatic cholestasis of pr...
# 4   2025-05-07  Kaftrio▼ (Ivacaftor, tezacaftor, elexacaftor):...
#
#                                                  url  \
# 0  https://www.gov.uk/drug-safety-update/abrysvov...
# 1  https://www.gov.uk/drug-safety-update/ixchiq-c...
# 2  https://www.gov.uk/drug-safety-update/valproat...
# 3  https://www.gov.uk/drug-safety-update/thiopuri...
# 4  https://www.gov.uk/drug-safety-update/kaftriov...
#
#                                               detail  alert_pdf  \
# 0  ## Cookies on GOV.UK\n\nWe use some essential ...        NaN
# 1  ## Cookies on GOV.UK\n\nWe use some essential ...        NaN
# 2  ## Cookies on GOV.UK\n\nWe use some essential ...        NaN
# 3  ## Cookies on GOV.UK\n\nWe use some essential ...        NaN
# 4  ## Cookies on GOV.UK\n\nWe use some essential ...        NaN
#
#                                                  pdf  \
# 0  https://assets.publishing.service.gov.uk/media...
# 1  https://assets.publishing.service.gov.uk/media...
# 2  https://assets.publishing.service.gov.uk/media...
# 3  https://assets.publishing.service.gov.uk/media...
# 4  https://assets.publishing.service.gov.uk/media...
#
#                                          therapeutic
# 0  Anaesthesia and intensive care, General practi...
# 1  Immunology and vaccination, Infection preventi...
# 2  General practice, Neurology, Obstetrics, gynae...
# 3  Cancer, Dermatology, GI, hepatology and pancre...
# 4  General practice, Pharmacy, Respiratory diseas...

# %%
df.to_csv('../data/data.csv', index=False)
